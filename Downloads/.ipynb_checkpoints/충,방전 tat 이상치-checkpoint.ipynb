# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')
import platform
plt.rcParams['font.family'] = 'Malgun Gothic' 
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('./C2_이차전지/bat_total.csv',encoding='euc-kr')
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#        rta1_cell_no rta1_box_col rta1_box_row rta1_box_dan  rta1_tat  \
# 0                16          02열          43연          07단    218091
# 1                11          02열          43연          07단    218091
# 2                24          02열          43연          07단    218091
# 3                 8          02열          43연          07단    218091
# 4                13          02열          43연          07단    218091
# ...             ...          ...          ...          ...       ...
# 37178            16          08열          21연          03단    152836
# 37179            14          08열          21연          03단    152836
# 37180             2          08열          21연          03단    152836
# 37181            15          08열          21연          03단    152836
# 37182            10          08열          21연          03단    152836
#
#       hta1_box_col hta1_box_row hta1_box_dan  hta1_tat rta2_box_col  ...  \
# 0              01열          14연          02단     86612          06열  ...
# 1              01열          14연          02단     86612          06열  ...
# 2              01열          14연          02단     86612          06열  ...
# 3              01열          14연          02단     86612          06열  ...
# 4              01열          14연          02단     86612          06열  ...
# ...            ...          ...          ...       ...          ...  ...
# 37178          02열          23연          06단     87334          03열  ...
# 37179          02열          23연          06단     87334          03열  ...
# 37180          02열          23연          06단     87334          03열  ...
# 37181          02열          23연          06단     87334          03열  ...
# 37182          02열          23연          06단     87334          03열  ...
#
#           cell_id judge            dt_start  m1_thick m1_voltage m1_res_ac  \
# 0      CELL-10649    양품  25NOV2023:20:47:00    4682.0    37603.0      91.0
# 1      CELL-10651    양품  25NOV2023:20:47:00    4738.0    37616.0      95.0
# 2      CELL-10652    양품  25NOV2023:20:47:00    4699.0    37602.0      92.0
# 3      CELL-10653    양품  25NOV2023:20:47:00    4730.0    37590.0      95.0
# 4      CELL-10654    양품  25NOV2023:20:47:00    4718.0    37595.0      95.0
# ...           ...   ...                 ...       ...        ...       ...
# 37178  CELL-53649    양품  11DEC2023:18:33:15    4745.0    37583.0      94.0
# 37179  CELL-53650    양품  11DEC2023:18:33:15    4746.0    37583.0      94.0
# 37180  CELL-53651    양품  11DEC2023:18:33:15    4782.0    37595.0      92.0
# 37181  CELL-54355    양품  11DEC2023:18:33:15    4751.0    37590.0      95.0
# 37182  CELL-54356    불량  11DEC2023:18:33:15    4792.0    37592.0      94.0
#
#        m1_mv  m1_voltage_an  is_defective  defect_rate
# 0      643.0           55.0             0          0.0
# 1      560.0          -46.0             0          0.0
# 2      622.0           53.0             0          0.0
# 3      581.0           10.0             0          0.0
# 4      581.0          120.0             0          0.0
# ...      ...            ...           ...          ...
# 37178  643.0          -35.0             0          0.2
# 37179  620.0           89.0             0          0.2
# 37180  597.0          -23.0             0          0.2
# 37181  620.0            3.0             0          0.2
# 37182  597.0           56.0             1          0.2
#
# [37183 rows x 166 columns]

# %% [raw]
# cols = df.select_dtypes(['int','float']).columns
#
# plt.figure(figsize=(12, len(cols) * 3))
#
# for i, column in enumerate(cols):
#     plt.subplot(len(cols), 1, i + 1)
#     sns.boxplot(y=df[column])
#     plt.title(f'Boxplot of {column}')
#
# plt.tight_layout()
# plt.show()

# %% [markdown]
# -----------

# %% [markdown]
# ### 충전1

# %%
sns.boxplot(df,y='c1_tat')
# Out:
# <Axes: ylabel='c1_tat'>

# %%
c1 = df[['tray_id','c1_capa','c1_curr_end','c1_tat','judge']]

c1['C-rate'] = c1['c1_curr_end'] / c1['c1_capa']

c1['time'] = (1/c1['C-rate']) * 3600

c1
# Out:
#          tray_id  c1_capa  c1_curr_end  c1_tat judge    C-rate         time
# 0      TRAY-1072     6477         6801    3595    양품  1.050023  3428.495809
# 1      TRAY-1072     6496         6802    3595    양품  1.047106  3438.047633
# 2      TRAY-1072     6457         6798    3595    양품  1.052811  3419.417476
# 3      TRAY-1072     6494         6802    3595    양품  1.047428  3436.989121
# 4      TRAY-1072     6569         6803    3595    양품  1.035622  3476.172277
# ...          ...      ...          ...     ...   ...       ...          ...
# 37178  TRAY-2791     6454         6799    3553    양품  1.053455  3417.326077
# 37179  TRAY-2791     6479         6800    3553    양품  1.049545  3430.058824
# 37180  TRAY-2791     6421         6800    3553    양품  1.059025  3399.352941
# 37181  TRAY-2791     6439         6802    3553    양품  1.056375  3407.880035
# 37182  TRAY-2791     6415         6799    3553    불량  1.059860  3396.675982
#
# [37183 rows x 7 columns]

# %%
a = c1[c1['c1_tat'] > 6000]
a['judge'].value_counts()
# Out:
# 양품    892
# 불량      7
# Name: judge, dtype: int64

# %% [markdown]
# - 불량 제외 평균으로 이상치 대체

# %%
c1['time'].mean()
# Out:
# 3424.5959948367804

# %%
a = df[df['c1_tat'] < 6000]
mean_c1 =a['c1_tat'].mean().round(3)

df.loc[df['c1_tat'] > 6000, 'c1_tat'] = mean_c1

# %% [markdown]
# ------------------------

# %% [markdown]
# ### 방전 1(Hmm..날리지 말자)

# %%
sns.boxplot(df,y='dc1_tat')
# Out:
# <Axes: ylabel='dc1_tat'>

# %%
dc1 = df[['tray_id','dc1_capa','dc1_curr_end','dc1_tat']]

dc1['C-rate'] = dc1['dc1_curr_end'] / dc1['dc1_capa']

dc1['time'] = (1/dc1['C-rate']) * 3600

dc1
# Out:
#          tray_id  dc1_capa  dc1_curr_end  dc1_tat     C-rate        time
# 0      TRAY-1072       544          6799      405  12.498162  288.042359
# 1      TRAY-1072       544          6800      405  12.500000  288.000000
# 2      TRAY-1072       544          6800      405  12.500000  288.000000
# 3      TRAY-1072       544          6799      405  12.498162  288.042359
# 4      TRAY-1072       545          6800      405  12.477064  288.529412
# ...          ...       ...           ...      ...        ...         ...
# 37178  TRAY-2791       545          6800      405  12.477064  288.529412
# 37179  TRAY-2791       544          6799      405  12.498162  288.042359
# 37180  TRAY-2791       544          6799      405  12.498162  288.042359
# 37181  TRAY-2791       544          6799      405  12.498162  288.042359
# 37182  TRAY-2791       544          6799      405  12.498162  288.042359
#
# [37183 rows x 6 columns]

# %%
dc1['time'].describe()
# Out:
# count    37183.000000
# mean       288.158101
# std          0.215502
# min        287.746106
# 25%        288.042359
# 50%        288.042359
# 75%        288.127115
# max        288.869258
# Name: time, dtype: float64

# %% [markdown]
# ----------

# %% [markdown]
# ### 충전2 (다시보자)

# %%
sns.boxplot(df,y='c2_tat')
# Out:
# <Axes: ylabel='c2_tat'>

# %%
c2 = df[['tray_id','c2_capa','c2_curr_end','c2_tat','judge']]

c2['C-rate'] = c2['c2_curr_end'] / c2['c2_capa']

c2['time'] = (1/c2['C-rate']) * 3600

c2
# Out:
#          tray_id  c2_capa  c2_curr_end  c2_tat judge     C-rate        time
# 0      TRAY-1072      616         6800     452    양품  11.038961  326.117647
# 1      TRAY-1072      618         6800     452    양품  11.003236  327.176471
# 2      TRAY-1072      629         6802     452    양품  10.813990  332.902088
# 3      TRAY-1072      619         6802     452    양품  10.988691  327.609527
# 4      TRAY-1072      613         6800     452    양품  11.092985  324.529412
# ...          ...      ...          ...     ...   ...        ...         ...
# 37178  TRAY-2791      614         6801     451    양품  11.076547  325.011028
# 37179  TRAY-2791      606         6801     451    양품  11.222772  320.776356
# 37180  TRAY-2791      624         6802     451    양품  10.900641  330.255807
# 37181  TRAY-2791      618         6801     451    양품  11.004854  327.128363
# 37182  TRAY-2791      631         6802     451    불량  10.779715  333.960600
#
# [37183 rows x 7 columns]

# %%
a = c2[c2['c2_tat']>1000]
a['judge'].value_counts()
# Out:
# 양품    21
# Name: judge, dtype: int64

# %%
sns.boxplot(c2,y='c2_capa')
# Out:
# <Axes: ylabel='c2_capa'>

# %% [markdown]
# - tat 기준 잡아서 날리자

# %%
b = c2[c2['c2_tat'] < 1000]
mean_c2 = b['c2_tat'].mean().round(3)
df.loc[df['c2_tat'] > 1000, 'c2_tat'] = mean_c2

# %%
df[df['c2_tat'] > 1000]
# Out:
# Empty DataFrame
# Columns: [rta1_cell_no, rta1_box_col, rta1_box_row, rta1_box_dan, rta1_tat, hta1_box_col, hta1_box_row, hta1_box_dan, hta1_tat, rta2_box_col, rta2_box_row, rta2_box_dan, rta2_tat, ocv1_ocv, ocv1_box_col, ocv1_box_dan, socv1_ocv, ocv1_deltaocv, socv1_tat, ocv1_tat, c1_curr_end, c1_voltage_avg, c1_capa, c1_ccval, c1_time_cc, c1_box_col, c1_box_dan, c1_temp_avg, dc1_curr_end, dc1_voltage_avg, dc1_capa, dc1_box_col, dc1_box_dan, dc1_temp_avg, dc1_capafit, pc1_imp, pc1_voltage_start, pc1_curr_end, pc1_box_col, pc1_box_dan, dc1_tat, pc1_tat, c1_tat, dc1_curr_end.1, dc1_voltage_avg.1, dc1_capa.1, dc1_box_col.1, dc1_box_dan.1, dc1_temp_avg.1, dc1_capafit.1, dc1_tat.1, c2_curr_end, c2_voltage_avg, c2_capa, c2_ccval, c2_time_cc, c2_box_col, c2_box_dan, c2_temp_avg, dc2_curr_end, dc2_voltage_avg, dc2_capa, dc2_box_col, dc2_box_dan, dc2_temp_avg, dc2_capafit, dc2_tat, c2_tat, dc2_curr_end.1, dc2_voltage_avg.1, dc2_capa.1, dc2_box_col.1, dc2_box_dan.1, dc2_temp_avg.1, dc2_capafit.1, dc2_tat.1, c3_curr_end, c3_voltage_avg, c3_capa, c3_ccval, c3_time_cv, c3_cvval, c3_time_cc, c3_box_col, c3_box_dan, c3_temp_avg, dc3_curr_end, dc3_voltage_avg, dc3_capa, dc3_box_col, dc3_box_dan, dc3_temp_avg, dc3_capafit, dc3_tat, c3_tat, dc3_curr_end.1, dc3_voltage_avg.1, dc3_capa.1, dc3_box_col.1, dc3_box_dan.1, ...]
# Index: []
#
# [0 rows x 166 columns]

# %% [raw]
# df = df[df['c2_tat']<1000]
#
# df[df['c2_tat']>1000]

# %% [markdown]
# ### 방전2(이 정도 편차는 발생할 수 있다)

# %%
sns.boxplot(df,y='dc2_tat')
# Out:
# <Axes: ylabel='dc2_tat'>

# %%
dc2 = df[['tray_id','dc2_capa','dc2_curr_end','dc2_tat','judge']]

dc2['C-rate'] = dc2['dc2_curr_end'] / dc2['dc2_capa']

dc2['time'] = (1/dc2['C-rate']) * 3600

dc2
# Out:
#          tray_id  dc2_capa  dc2_curr_end  dc2_tat judge     C-rate        time
# 0      TRAY-1072       544          6798      405    양품  12.496324  288.084731
# 1      TRAY-1072       544          6800      405    양품  12.500000  288.000000
# 2      TRAY-1072       544          6800      405    양품  12.500000  288.000000
# 3      TRAY-1072       545          6800      405    양품  12.477064  288.529412
# 4      TRAY-1072       544          6799      405    양품  12.498162  288.042359
# ...          ...       ...           ...      ...   ...        ...         ...
# 37178  TRAY-2791       544          6799      405    양품  12.498162  288.042359
# 37179  TRAY-2791       544          6799      405    양품  12.498162  288.042359
# 37180  TRAY-2791       544          6799      405    양품  12.498162  288.042359
# 37181  TRAY-2791       544          6799      405    양품  12.498162  288.042359
# 37182  TRAY-2791       544          6799      405    불량  12.498162  288.042359
#
# [37183 rows x 7 columns]

# %%
a = dc2[dc2['dc2_tat'] > 460]
a['judge'].value_counts()
# Out:
# 양품    24
# Name: judge, dtype: int64

# %%
b = dc2[dc2['dc2_tat'] < 460]
mean_dc2 = b.mean().round(3)
df.loc[df['dc2_tat'] > 460, 'dc2_tat'] = mean_dc2

# %%
df[df['dc2_tat'] > 460]
# Out:
# Empty DataFrame
# Columns: [rta1_cell_no, rta1_box_col, rta1_box_row, rta1_box_dan, rta1_tat, hta1_box_col, hta1_box_row, hta1_box_dan, hta1_tat, rta2_box_col, rta2_box_row, rta2_box_dan, rta2_tat, ocv1_ocv, ocv1_box_col, ocv1_box_dan, socv1_ocv, ocv1_deltaocv, socv1_tat, ocv1_tat, c1_curr_end, c1_voltage_avg, c1_capa, c1_ccval, c1_time_cc, c1_box_col, c1_box_dan, c1_temp_avg, dc1_curr_end, dc1_voltage_avg, dc1_capa, dc1_box_col, dc1_box_dan, dc1_temp_avg, dc1_capafit, pc1_imp, pc1_voltage_start, pc1_curr_end, pc1_box_col, pc1_box_dan, dc1_tat, pc1_tat, c1_tat, dc1_curr_end.1, dc1_voltage_avg.1, dc1_capa.1, dc1_box_col.1, dc1_box_dan.1, dc1_temp_avg.1, dc1_capafit.1, dc1_tat.1, c2_curr_end, c2_voltage_avg, c2_capa, c2_ccval, c2_time_cc, c2_box_col, c2_box_dan, c2_temp_avg, dc2_curr_end, dc2_voltage_avg, dc2_capa, dc2_box_col, dc2_box_dan, dc2_temp_avg, dc2_capafit, dc2_tat, c2_tat, dc2_curr_end.1, dc2_voltage_avg.1, dc2_capa.1, dc2_box_col.1, dc2_box_dan.1, dc2_temp_avg.1, dc2_capafit.1, dc2_tat.1, c3_curr_end, c3_voltage_avg, c3_capa, c3_ccval, c3_time_cv, c3_cvval, c3_time_cc, c3_box_col, c3_box_dan, c3_temp_avg, dc3_curr_end, dc3_voltage_avg, dc3_capa, dc3_box_col, dc3_box_dan, dc3_temp_avg, dc3_capafit, dc3_tat, c3_tat, dc3_curr_end.1, dc3_voltage_avg.1, dc3_capa.1, dc3_box_col.1, dc3_box_dan.1, ...]
# Index: []
#
# [0 rows x 166 columns]

# %% [markdown]
# --------------

# %% [markdown]
# ### 충전3 (토의 필요)

# %%
sns.boxplot(df,y='c3_tat')
# Out:
# <Axes: ylabel='c3_tat'>

# %%
c3 = df[['tray_id','c3_capa','c3_curr_end','c3_tat','judge']]

c3['C-rate'] = c3['c3_curr_end'] / c3['c3_capa']

c3['time'] = (1/c3['C-rate']) * 3600

c3
# Out:
#          tray_id  c3_capa  c3_curr_end  c3_tat judge    C-rate          time
# 0      TRAY-1072      740          136    1841    양품  0.183784  19588.235294
# 1      TRAY-1072      756          136    1841    양품  0.179894  20011.764706
# 2      TRAY-1072      742          136    1841    양품  0.183288  19641.176471
# 3      TRAY-1072      722          136    1841    양품  0.188366  19111.764706
# 4      TRAY-1072      730          136    1841    양품  0.186301  19323.529412
# ...          ...      ...          ...     ...   ...       ...           ...
# 37178  TRAY-2791      743          136    1854    양품  0.183042  19667.647059
# 37179  TRAY-2791      727          136    1854    양품  0.187070  19244.117647
# 37180  TRAY-2791      765          136    1854    양품  0.177778  20250.000000
# 37181  TRAY-2791      742          136    1854    양품  0.183288  19641.176471
# 37182  TRAY-2791      757          136    1854    불량  0.179657  20038.235294
#
# [37183 rows x 7 columns]

# %%
a= c3[c3['c3_tat'] > 4000]
a
# Out:
#          tray_id  c3_capa  c3_curr_end  c3_tat judge    C-rate          time
# 4817   TRAY-1299      719          136    6073    양품  0.189152  19032.352941
# 4818   TRAY-1299      723          136    6073    양품  0.188105  19138.235294
# 4819   TRAY-1299      734          136    6073    양품  0.185286  19429.411765
# 4820   TRAY-1299      727          136    6073    양품  0.187070  19244.117647
# 4821   TRAY-1299      725          136    6073    양품  0.187586  19191.176471
# ...          ...      ...          ...     ...   ...       ...           ...
# 31893  TRAY-2529      709          136    6640    양품  0.191819  18767.647059
# 31894  TRAY-2529      721          136    6640    양품  0.188627  19085.294118
# 31895  TRAY-2529      724          136    6640    양품  0.187845  19164.705882
# 31896  TRAY-2529      722          136    6640    양품  0.188366  19111.764706
# 31897  TRAY-2529      748          136    6640    양품  0.181818  19800.000000
#
# [124 rows x 7 columns]

# %%
c3['c3_capa'].describe()
# Out:
# count    37183.000000
# mean       734.345265
# std         23.219402
# min        658.000000
# 25%        724.000000
# 50%        734.000000
# 75%        745.000000
# max       1399.000000
# Name: c3_capa, dtype: float64

# %%
a['c3_capa'].describe()
# Out:
# count     124.000000
# mean      721.500000
# std        66.819682
# min       667.000000
# 25%       691.000000
# 50%       719.000000
# 75%       733.250000
# max      1211.000000
# Name: c3_capa, dtype: float64

# %%
a['judge'].value_counts()
# Out:
# 양품    72
# Name: judge, dtype: int64

# %% [markdown]
# - tat 튀는건 다 양품

# %%
sns.boxplot(c3,y='c3_capa')
# Out:
# <Axes: ylabel='c3_capa'>

# %%
b = c3[c3['c3_capa'] > 1000]
b['judge'].value_counts()
# Out:
# 양품    32
# Name: judge, dtype: int64

# %% [markdown]
# - 용량, tat 튐, 안겹침, 모두 양품 -> 평균으로 대체한다?
# - tat만 고려?

# %% [markdown]
# ---------

# %% [markdown]
# ### 방전3

# %%
sns.boxplot(df,y='dc3_tat')
# Out:
# <Axes: ylabel='dc3_tat'>

# %%
dc3 = df[['tray_id','dc3_capa','dc3_curr_end','dc3_tat']]

dc3['C-rate'] = dc3['dc3_curr_end'] / dc3['dc3_capa']

dc3['time'] = (1/dc3['C-rate']) * 3600

dc3
# Out:
#          tray_id  dc3_capa  dc3_curr_end  dc3_tat    C-rate         time
# 0      TRAY-1072      7076          6798     3909  0.960712  3747.219771
# 1      TRAY-1072      7088          6799     3909  0.959227  3753.022503
# 2      TRAY-1072      7093          6797     3909  0.958269  3756.775048
# 3      TRAY-1072      7138          6799     3909  0.952508  3779.496985
# 4      TRAY-1072      7147          6798     3909  0.951168  3784.819064
# ...          ...       ...           ...      ...       ...          ...
# 37178  TRAY-2791      7071          6798     3888  0.961392  3744.571933
# 37179  TRAY-2791      7087          6799     3888  0.959362  3752.493014
# 37180  TRAY-2791      7069          6797     3888  0.961522  3744.063557
# 37181  TRAY-2791      7060          6796     3888  0.962606  3739.846969
# 37182  TRAY-2791      7059          6799     3888  0.963168  3737.667304
#
# [37183 rows x 6 columns]

# %%
a = df[df['dc3_tat'] < 7000]
mean_dc3 = a.mean().round(3)
df.loc[df['dc3_tat'] > 7000, 'dc3_tat'] = mean_dc3

# %%
df[df['dc3_tat'] > 7000]
# Out:
# Empty DataFrame
# Columns: [rta1_cell_no, rta1_box_col, rta1_box_row, rta1_box_dan, rta1_tat, hta1_box_col, hta1_box_row, hta1_box_dan, hta1_tat, rta2_box_col, rta2_box_row, rta2_box_dan, rta2_tat, ocv1_ocv, ocv1_box_col, ocv1_box_dan, socv1_ocv, ocv1_deltaocv, socv1_tat, ocv1_tat, c1_curr_end, c1_voltage_avg, c1_capa, c1_ccval, c1_time_cc, c1_box_col, c1_box_dan, c1_temp_avg, dc1_curr_end, dc1_voltage_avg, dc1_capa, dc1_box_col, dc1_box_dan, dc1_temp_avg, dc1_capafit, pc1_imp, pc1_voltage_start, pc1_curr_end, pc1_box_col, pc1_box_dan, dc1_tat, pc1_tat, c1_tat, dc1_curr_end.1, dc1_voltage_avg.1, dc1_capa.1, dc1_box_col.1, dc1_box_dan.1, dc1_temp_avg.1, dc1_capafit.1, dc1_tat.1, c2_curr_end, c2_voltage_avg, c2_capa, c2_ccval, c2_time_cc, c2_box_col, c2_box_dan, c2_temp_avg, dc2_curr_end, dc2_voltage_avg, dc2_capa, dc2_box_col, dc2_box_dan, dc2_temp_avg, dc2_capafit, dc2_tat, c2_tat, dc2_curr_end.1, dc2_voltage_avg.1, dc2_capa.1, dc2_box_col.1, dc2_box_dan.1, dc2_temp_avg.1, dc2_capafit.1, dc2_tat.1, c3_curr_end, c3_voltage_avg, c3_capa, c3_ccval, c3_time_cv, c3_cvval, c3_time_cc, c3_box_col, c3_box_dan, c3_temp_avg, dc3_curr_end, dc3_voltage_avg, dc3_capa, dc3_box_col, dc3_box_dan, dc3_temp_avg, dc3_capafit, dc3_tat, c3_tat, dc3_curr_end.1, dc3_voltage_avg.1, dc3_capa.1, dc3_box_col.1, dc3_box_dan.1, ...]
# Index: []
#
# [0 rows x 166 columns]

# %% [markdown]
# ---------

# %% [markdown]
# ### 충전4 (토의 필요)

# %%
sns.boxplot(df,y='c4_tat')
# Out:
# <Axes: ylabel='c4_tat'>

# %%
c4 = df[['tray_id','c4_capa','c4_curr_end','c4_tat']]

c4['C-rate'] = c4['c4_curr_end'] / c4['c4_capa']

c4['time'] = (1/c4['C-rate']) * 3600

c4
# Out:
#          tray_id  c4_capa  c4_curr_end  c4_tat    C-rate           time
# 0      TRAY-1072     4296          135    3523  0.031425  114560.000000
# 1      TRAY-1072     4324          136    3523  0.031452  114458.823529
# 2      TRAY-1072     4288          136    3523  0.031716  113505.882353
# 3      TRAY-1072     4298          136    3523  0.031643  113770.588235
# 4      TRAY-1072     4324          136    3523  0.031452  114458.823529
# ...          ...      ...          ...     ...       ...            ...
# 37178  TRAY-2791     4265          136    3462  0.031887  112897.058824
# 37179  TRAY-2791     4276          136    3462  0.031805  113188.235294
# 37180  TRAY-2791     4272          136    3462  0.031835  113082.352941
# 37181  TRAY-2791     4261          136    3462  0.031917  112791.176471
# 37182  TRAY-2791     4253          136    3462  0.031977  112579.411765
#
# [36284 rows x 6 columns]

# %%
c4[c4['c4_tat'] > 15000]
# Out:
#         tray_id  c4_capa  c4_curr_end  c4_tat    C-rate           time
# 6550  TRAY-1398     4289          135   15506  0.031476  114373.333333
# 6551  TRAY-1398     4313          136   15506  0.031533  114167.647059
# 6552  TRAY-1398     4315          136   15506  0.031518  114220.588235
# 6553  TRAY-1398     4310          135   15506  0.031323  114933.333333
# 6554  TRAY-1398     4303          136   15506  0.031606  113902.941176
# 6555  TRAY-1398     4306          136   15506  0.031584  113982.352941
# 6556  TRAY-1398     4285          135   15506  0.031505  114266.666667
# 6557  TRAY-1398     4306          136   15506  0.031584  113982.352941
# 6558  TRAY-1398     4300          136   15506  0.031628  113823.529412
# 6559  TRAY-1398     4300          136   15506  0.031628  113823.529412
# 6560  TRAY-1398     4321          136   15506  0.031474  114379.411765
# 6561  TRAY-1398     4273          136   15506  0.031828  113108.823529
# 6562  TRAY-1398     4306          136   15506  0.031584  113982.352941
# 6563  TRAY-1398     4306          136   15506  0.031584  113982.352941
# 6564  TRAY-1398     4304          136   15506  0.031599  113929.411765
# 6565  TRAY-1398     4323          136   15506  0.031460  114432.352941
# 6566  TRAY-1398     4287          136   15506  0.031724  113479.411765
# 6567  TRAY-1398     4302          136   15506  0.031613  113876.470588
# 6568  TRAY-1398     4297          136   15506  0.031650  113744.117647
# 6569  TRAY-1398     4306          135   15506  0.031352  114826.666667
# 6570  TRAY-1398     4287          135   15506  0.031491  114320.000000

# %%
c4['c4_capa'].describe()
# Out:
# count    36284.000000
# mean      4285.895712
# std         17.742203
# min       4161.000000
# 25%       4275.000000
# 50%       4285.000000
# 75%       4297.000000
# max       4382.000000
# Name: c4_capa, dtype: float64

# %%
sns.boxplot(c4,y='c4_capa')
# Out:
# <Axes: ylabel='c4_capa'>

# %% [markdown]
# - 용량은 모두 비슷, tat 기준 잡아서 날리자

# %% [markdown]
# -------

# %%
df
# Out:
#        rta1_cell_no rta1_box_col rta1_box_row rta1_box_dan  rta1_tat  \
# 0                16          02열          43연          07단    218091
# 1                11          02열          43연          07단    218091
# 2                24          02열          43연          07단    218091
# 3                 8          02열          43연          07단    218091
# 4                13          02열          43연          07단    218091
# ...             ...          ...          ...          ...       ...
# 37178            16          08열          21연          03단    152836
# 37179            14          08열          21연          03단    152836
# 37180             2          08열          21연          03단    152836
# 37181            15          08열          21연          03단    152836
# 37182            10          08열          21연          03단    152836
#
#       hta1_box_col hta1_box_row hta1_box_dan  hta1_tat rta2_box_col  ...  \
# 0              01열          14연          02단     86612          06열  ...
# 1              01열          14연          02단     86612          06열  ...
# 2              01열          14연          02단     86612          06열  ...
# 3              01열          14연          02단     86612          06열  ...
# 4              01열          14연          02단     86612          06열  ...
# ...            ...          ...          ...       ...          ...  ...
# 37178          02열          23연          06단     87334          03열  ...
# 37179          02열          23연          06단     87334          03열  ...
# 37180          02열          23연          06단     87334          03열  ...
# 37181          02열          23연          06단     87334          03열  ...
# 37182          02열          23연          06단     87334          03열  ...
#
#           cell_id judge            dt_start  m1_thick m1_voltage m1_res_ac  \
# 0      CELL-10649    양품  25NOV2023:20:47:00    4682.0    37603.0      91.0
# 1      CELL-10651    양품  25NOV2023:20:47:00    4738.0    37616.0      95.0
# 2      CELL-10652    양품  25NOV2023:20:47:00    4699.0    37602.0      92.0
# 3      CELL-10653    양품  25NOV2023:20:47:00    4730.0    37590.0      95.0
# 4      CELL-10654    양품  25NOV2023:20:47:00    4718.0    37595.0      95.0
# ...           ...   ...                 ...       ...        ...       ...
# 37178  CELL-53649    양품  11DEC2023:18:33:15    4745.0    37583.0      94.0
# 37179  CELL-53650    양품  11DEC2023:18:33:15    4746.0    37583.0      94.0
# 37180  CELL-53651    양품  11DEC2023:18:33:15    4782.0    37595.0      92.0
# 37181  CELL-54355    양품  11DEC2023:18:33:15    4751.0    37590.0      95.0
# 37182  CELL-54356    불량  11DEC2023:18:33:15    4792.0    37592.0      94.0
#
#        m1_mv  m1_voltage_an  is_defective  defect_rate
# 0      643.0           55.0             0          0.0
# 1      560.0          -46.0             0          0.0
# 2      622.0           53.0             0          0.0
# 3      581.0           10.0             0          0.0
# 4      581.0          120.0             0          0.0
# ...      ...            ...           ...          ...
# 37178  643.0          -35.0             0          0.2
# 37179  620.0           89.0             0          0.2
# 37180  597.0          -23.0             0          0.2
# 37181  620.0            3.0             0          0.2
# 37182  597.0           56.0             1          0.2
#
# [37183 rows x 166 columns]

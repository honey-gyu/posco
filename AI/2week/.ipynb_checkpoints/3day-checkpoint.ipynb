# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import Model, layers
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# Out:
# 2024-09-05 13:21:47.877924: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-05 13:21:47.879288: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-05 13:21:47.883247: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-05 13:21:47.896691: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-05 13:21:47.919459: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-05 13:21:47.926225: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-05 13:21:47.942195: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-05 13:21:48.943910: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print(e)

# %%
def convolution_layer_test(filters, kernel_size, s = 1, p = 'valid', input_size = [1, 64, 64, 3]):
    inputs = tf.random.normal(input_size)
    print('input size: ', inputs.shape)
    conv = tf.keras.layers.Conv2D(filters, kernel_size, strides = s, padding = p)
    outputs = conv(inputs)
    print('output size: ', outputs.shape)

# %%
def pooling_layer_test(pool_size, s = 1, p = 'valid', input_size = [1, 64, 64 ,3]):
    inputs = tf.random.normal(input_size)
    print('input size: ', inputs.shape)
    pool = tf.keras.layers.MaxPool2D(pool_size, strides = s, padding = p)
    outputs = pool(inputs)
    print('output size: ', outputs.shape)

# %%
convolution_layer_test(10, 11, s = 6, p = 'same', input_size = [1, 128, 128, 3])
# Out:
# input size:  (1, 128, 128, 3)
# output size:  (1, 22, 22, 10)

# %%
convolution_layer_test(100, 3)
# Out:
# input size:  (1, 64, 64, 3)
# output size:  (1, 62, 62, 100)

# %%
convolution_layer_test(100, 3, p = 'same')
# Out:
# input size:  (1, 64, 64, 3)
# output size:  (1, 64, 64, 100)

# %%
convolution_layer_test(100, 3, s = 3, p = 'same')
# Out:
# input size:  (1, 64, 64, 3)
# output size:  (1, 22, 22, 100)

# %%
pooling_layer_test(2)
# Out:
# input size:  (1, 64, 64, 3)
# output size:  (1, 63, 63, 3)

# %%
pooling_layer_test(2, p = 'same')
# Out:
# input size:  (1, 64, 64, 3)
# output size:  (1, 64, 64, 3)

# %%
(x_trainval, y_trainval), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
print(type(x_trainval), x_trainval.shape)
print(type(y_trainval), y_trainval.shape)

x_train, x_valid, y_train, y_valid = train_test_split(x_trainval, y_trainval, test_size = 1/6, shuffle = True,
                                                     stratify = y_trainval, random_state = 34)
print(type(x_train), x_train.shape)
print(type(y_train), y_train.shape)
# Out:
# <class 'numpy.ndarray'> (60000, 28, 28)
# <class 'numpy.ndarray'> (60000,)
# <class 'numpy.ndarray'> (50000, 28, 28)
# <class 'numpy.ndarray'> (50000,)

# %%
plt.imshow(x_train[0])

# %%
x_train, x_valid, x_test = x_train.astype('float32') / 255, x_valid.astype('float32') / 255, x_test.astype('float32') / 255

x_train = x_train.reshape(-1, 28, 28, 1)
x_valid = x_valid.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

print(x_train.shape, x_valid.shape, x_test.shape)
print(y_train.shape, y_valid.shape, y_test.shape)
# Out:
# (50000, 28, 28, 1) (10000, 28, 28, 1) (10000, 28, 28, 1)
# (50000,) (10000,) (10000,)

# %%
cnn = Sequential()

cnn.add(layers.Conv2D(32, 3, strides = 1, padding = 'same', activation = 'relu', input_shape= (28, 28, 1)))
cnn.add(layers.MaxPool2D(3, strides = 2, padding = 'same'))
cnn.add(layers.Conv2D(64, 3, strides = 1, padding = 'same', activation = 'relu'))
cnn.add(layers.Flatten())
cnn.add(layers.Dense(128, activation = 'relu'))
cnn.add(layers.Dense(10, activation = 'softmax'))
# Out:
# /home/piai/anaconda3/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.compile(loss = 'sparse_categorical_crossentropy', optimizer = tf.keras.optimizers.SGD(learning_rate = 0.01),
           metrics = ['accuracy'])

# %%
result = cnn.fit(x_train, y_train, epochs = 5, batch_size = 128, validation_data = (x_valid, y_valid))
# Out:
# Epoch 1/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.5886 - loss: 1.4440 - val_accuracy: 0.8283 - val_loss: 0.5145
# Epoch 2/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.8943 - loss: 0.3421 - val_accuracy: 0.9133 - val_loss: 0.2820
# Epoch 3/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.9196 - loss: 0.2596 - val_accuracy: 0.9352 - val_loss: 0.2336
# Epoch 4/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.9339 - loss: 0.2183 - val_accuracy: 0.9342 - val_loss: 0.2161
# Epoch 5/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.9424 - loss: 0.1891 - val_accuracy: 0.9454 - val_loss: 0.1890

# %%
test_result = cnn.evaluate(x_test, y_test)
print('test loss: ', test_result[0])
print('test acc: ', test_result[1])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9435 - loss: 0.1928
# test loss:  0.17576304078102112
# test acc:  0.9492999911308289

# %%
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('CNN ACCURACY')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.grid()
plt.legend(['train', 'validation'], loc = 'best')

# %%
data = [x_train, y_train, x_valid, y_valid, x_test, y_test]

def train(model, x_train, y_train, x_valid, y_valid, x_test, y_test, epoch = 10, lr = 0.1):
    model.compile(loss = 'sparse_categorical_crossentropy', optimizer = tf.keras.optimizers.SGD(learning_rate = lr),
                 metrics = ['accuracy'])
    result = model.fit(x_train, y_train, epochs = epoch, batch_size = 128, validation_data = (x_valid, y_valid))
    test_result = cnn.evaluate(x_test, y_test)
    
    plt.plot(result.history['accuracy'])
    plt.plot(result.history['val_accuracy'])
    plt.title('CNN ACCURACY')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.grid()
    plt.legend(['train', 'validation'], loc = 'best')

# %%
train(cnn, *data, epoch = 3)
# Out:
# Epoch 1/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.7594 - loss: 1.1214 - val_accuracy: 0.9676 - val_loss: 0.1125
# Epoch 2/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.9701 - loss: 0.0941 - val_accuracy: 0.9762 - val_loss: 0.0818
# Epoch 3/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.9803 - loss: 0.0624 - val_accuracy: 0.9762 - val_loss: 0.0748
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9740 - loss: 0.0757

# %%
class CNN(Model):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = layers.Conv2D(32, 3, strides = 1, padding = 'same', activation = 'relu',
                                  input_shape = (28, 28, 1))
        self.maxpool1 = layers.MaxPool2D(3, strides = 2, padding = 'same')
        self.conv2 = layers.Conv2D(64, 3, strides = 1, padding = 'same', activation = 'relu')
        self.maxpool2 = layers.MaxPool2D(3, strides = 2, padding = 'same')
        self.flatten = layers.Flatten()
        self.fc1 = layers.Dense(128, activation = 'relu')
        self.fc2 = layers.Dense(10, activation = 'softmax')
        
    def call(self, x):
        x = self.conv1(x)
        x = self.maxpool1(x)
        x = self.conv2(x)
        x = self.maxpool2(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)
    
        return x

# %%
cnn = CNN()
train(cnn, *data)
# Out:
# Epoch 1/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.7155 - loss: 0.8955 - val_accuracy: 0.9608 - val_loss: 0.1234
# Epoch 2/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9693 - loss: 0.0964 - val_accuracy: 0.9752 - val_loss: 0.0762
# Epoch 3/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9789 - loss: 0.0660 - val_accuracy: 0.9797 - val_loss: 0.0637
# Epoch 4/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9834 - loss: 0.0546 - val_accuracy: 0.9851 - val_loss: 0.0497
# Epoch 5/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9881 - loss: 0.0408 - val_accuracy: 0.9861 - val_loss: 0.0488
# Epoch 6/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9887 - loss: 0.0363 - val_accuracy: 0.9793 - val_loss: 0.0648
# Epoch 7/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9903 - loss: 0.0298 - val_accuracy: 0.9880 - val_loss: 0.0395
# Epoch 8/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9909 - loss: 0.0276 - val_accuracy: 0.9873 - val_loss: 0.0441
# Epoch 9/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9924 - loss: 0.0254 - val_accuracy: 0.9884 - val_loss: 0.0400
# Epoch 10/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9933 - loss: 0.0219 - val_accuracy: 0.9892 - val_loss: 0.0382
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9882 - loss: 0.0347

# %%
class CNN(Model):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = layers.Conv2D(32, 3, strides = 1, padding = 'same', activation = 'relu', input_shape = (32, 32, 3))
        self.conv2 = layers.Conv2D(32, 3, strides = 1, padding = 'same', activation = 'relu')
        self.maxpool1 = layers.MaxPool2D(3, strides = 2, padding = 'same')
        self.conv3 = layers.Conv2D(64, 3, strides = 1, padding = 'same', activation = 'relu')
        self.conv4 = layers.Conv2D(64, 3, strides = 1, padding = 'same', activation = 'relu')
        self.maxpool2 = layers.MaxPool2D(3, strides = 2, padding = 'same')
        self.flatten = layers.Flatten()
        self.fc1 = layers.Dense(128, activation = 'relu')
        self.fc2 = layers.Dense(10, activation = 'softmax')
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.maxpool1(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.maxpool2(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)
        
        return x

# %%
cnn = CNN()
train(cnn, *data)
# Out:
# Epoch 1/10
# /home/piai/anaconda3/lib/python3.10/site-packages/keras/src/layers/layer.py:372: UserWarning: `build()` was called on layer 'cnn_1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 27s 68ms/step - accuracy: 0.6545 - loss: 1.0660 - val_accuracy: 0.9649 - val_loss: 0.1075
# Epoch 2/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 27s 69ms/step - accuracy: 0.9766 - loss: 0.0750 - val_accuracy: 0.9823 - val_loss: 0.0600
# Epoch 3/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 27s 69ms/step - accuracy: 0.9839 - loss: 0.0473 - val_accuracy: 0.9844 - val_loss: 0.0509
# Epoch 4/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 27s 70ms/step - accuracy: 0.9887 - loss: 0.0354 - val_accuracy: 0.9697 - val_loss: 0.1051
# Epoch 5/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - accuracy: 0.9906 - loss: 0.0288 - val_accuracy: 0.9873 - val_loss: 0.0411
# Epoch 6/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - accuracy: 0.9917 - loss: 0.0243 - val_accuracy: 0.9862 - val_loss: 0.0473
# Epoch 7/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - accuracy: 0.9935 - loss: 0.0187 - val_accuracy: 0.9888 - val_loss: 0.0392
# Epoch 8/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - accuracy: 0.9951 - loss: 0.0156 - val_accuracy: 0.9870 - val_loss: 0.0411
# Epoch 9/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - accuracy: 0.9964 - loss: 0.0123 - val_accuracy: 0.9870 - val_loss: 0.0487
# Epoch 10/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - accuracy: 0.9967 - loss: 0.0094 - val_accuracy: 0.9888 - val_loss: 0.0408
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9877 - loss: 0.0378

# %%
class CNN(Model):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = layers.Conv2D(32, 3, strides = 1, padding = 'same', input_shape = (32, 32, 3))
        self.bn1 = layers.BatchNormalization()
        self.maxpool1 = layers.MaxPool2D(3, strides = 2, padding = 'same')
        self.conv2 = layers.Conv2D(64, 3, strides = 1, padding = 'same')
        self.bn2 = layers.BatchNormalization()
        self.maxpool2 = layers.MaxPool2D(3, strides = 2, padding = 'same')
        self.flatten = layers.Flatten()
        self.fc1 = layers.Dense(128, activation = 'relu')
        self.fc2 = layers.Dense(10, activation = 'softmax')
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool1(x) 
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)
        x = self.maxpool2(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)
        
        return x

# %%
cnn = CNN()
train(cnn, *data)
# Out:
# Epoch 1/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.6952 - loss: 0.9740 - val_accuracy: 0.9737 - val_loss: 0.0906
# Epoch 2/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.9722 - loss: 0.0875 - val_accuracy: 0.9442 - val_loss: 0.1721
# Epoch 3/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.9797 - loss: 0.0622 - val_accuracy: 0.9818 - val_loss: 0.0582
# Epoch 4/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.9855 - loss: 0.0481 - val_accuracy: 0.9834 - val_loss: 0.0526
# Epoch 5/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.9880 - loss: 0.0370 - val_accuracy: 0.9880 - val_loss: 0.0404
# Epoch 6/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - accuracy: 0.9897 - loss: 0.0311 - val_accuracy: 0.9849 - val_loss: 0.0466
# Epoch 7/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.9910 - loss: 0.0287 - val_accuracy: 0.9849 - val_loss: 0.0463
# Epoch 8/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.9916 - loss: 0.0252 - val_accuracy: 0.9870 - val_loss: 0.0393
# Epoch 9/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.9925 - loss: 0.0234 - val_accuracy: 0.9888 - val_loss: 0.0386
# Epoch 10/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.9944 - loss: 0.0185 - val_accuracy: 0.9793 - val_loss: 0.0605
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9813 - loss: 0.0559

# %%
def make_conv_block(num_filters, filter_size, stride, padding = 'same', input_shape = None):
    conv_block = tf.keras.Sequential()
    if input_shape is not None:
        conv_block.add(layers.Conv2D(num_filters, filter_size, strides = stride, padding = padding,
                                    input_shape = input_shape))
    conv_block.add(layers.Conv2D(num_filters, filter_size, strides = stride, padding = padding))
    conv_block.add(layers.BatchNormalization())
    conv_block.add(layers.ReLU())
    return conv_block

# %%
class CNN(Model):
    def __init__(self):
        super(CNN, self).__init__()
        #self.conv1 = make_conv_block(32, 3, 1, 'same', (32, 32, 3)) 예시에는 3인데 입력 채널 수가 3(RGB 이미지)를 기대
        # 하고 있지만 실제로 들어온 입력은 (None, 28, 28, 1)로 채널 수가 1(흑백 이미지)이다.
        # 해결방법 1 (If) 만약 모델이 반드시 3채널 이미지를 받아야 한다면 흑백 이미지를 3채널로 변환
        # import numpy as np
        # def convert_to_rgb(grayscale_images):
        #    retrun np.repeat9grayscale_images, 3, axis = -1)
        # data = convert_to_rgb(data)
        
        # 해결방법 2 모델 입력을 흑백(1채널) 이미지로 맞추기
        # 아래와 같이 바꿈
        self.conv1 = make_conv_block(32, 3, 1, 'same', (32, 32, 1)) # 3채널에서 1채널로
        self.conv2 = make_conv_block(32, 3, 1, 'same')
        self.maxpool1 = layers.MaxPool2D(3, strides = 2, padding = 'same')
        
        self.conv3 = make_conv_block(64, 3, 1, 'same')
        self.conv4 = make_conv_block(64, 3, 1, 'same')
        self.maxpool2 = layers.MaxPool2D(3, strides = 2, padding = 'same')
        
        self.flatten = layers.Flatten()
        self.fc1 = layers.Dense(128, activation = 'relu')
        self.fc2 = layers.Dense(10, activation = 'softmax')
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.maxpool1(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.maxpool2(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)
        
        return x

# %%
cnn = CNN()
train(cnn, *data)
# Out:
# Epoch 1/10
# /home/piai/anaconda3/lib/python3.10/site-packages/keras/src/layers/layer.py:372: UserWarning: `build()` was called on layer 'cnn_5', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 34s 84ms/step - accuracy: 0.6028 - loss: 1.1760 - val_accuracy: 0.9755 - val_loss: 0.0752
# Epoch 2/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 32s 83ms/step - accuracy: 0.9781 - loss: 0.0665 - val_accuracy: 0.9854 - val_loss: 0.0502
# Epoch 3/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 83ms/step - accuracy: 0.9870 - loss: 0.0413 - val_accuracy: 0.9878 - val_loss: 0.0401
# Epoch 4/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 83ms/step - accuracy: 0.9902 - loss: 0.0291 - val_accuracy: 0.9878 - val_loss: 0.0406
# Epoch 5/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 83ms/step - accuracy: 0.9917 - loss: 0.0274 - val_accuracy: 0.9526 - val_loss: 0.1463
# Epoch 6/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 84ms/step - accuracy: 0.9932 - loss: 0.0222 - val_accuracy: 0.9879 - val_loss: 0.0449
# Epoch 7/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 34s 86ms/step - accuracy: 0.9949 - loss: 0.0163 - val_accuracy: 0.9864 - val_loss: 0.0467
# Epoch 8/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 34s 86ms/step - accuracy: 0.9949 - loss: 0.0145 - val_accuracy: 0.9908 - val_loss: 0.0336
# Epoch 9/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 34s 87ms/step - accuracy: 0.9967 - loss: 0.0111 - val_accuracy: 0.9909 - val_loss: 0.0329
# Epoch 10/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 34s 87ms/step - accuracy: 0.9970 - loss: 0.0095 - val_accuracy: 0.9887 - val_loss: 0.0385
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9884 - loss: 0.0356

# %%
class ConvBlock(layers.Layer):
    def __init__(self, num_filters, filter_size, stride, padding = 'same', input_shape = None):
        super(ConvBlock, self).__init__()
        if input_shape is not None:
            self.conv = layers.Conv2D(num_filters, filter_size, strides = stride, padding = padding,
                                     input_shape = input_shape)
        else:
            self.conv = layers.Conv2D(num_filters, filter_size, strides = stride, padding = padding)
        self.bn = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        
        return x

# %%
class CNN(Model):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = ConvBlock(32, 3, 1, 'same', (32, 32, 3))
        self.conv2 = ConvBlock(32, 3, 1, 'same')
        self.maxpool1 = layers.MaxPool2D(3, strides = 2, padding = 'same')
        
        self.conv3 = ConvBlock(64, 3, 1, 'same')
        self.conv4 = ConvBlock(64, 3, 1, 'same')
        self.maxpool2 = layers.MaxPool2D(3, strides = 2, padding = 'same')
        
        self.flatten = layers.Flatten()
        self.fc1 = layers.Dense(128, activation = 'relu')
        self.fc2 = layers.Dense(10, activation = 'softmax')
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.maxpool1(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.maxpool2(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)
        
        return x

# %%
cnn = CNN()
train(cnn, *data)
# Out:
# Epoch 1/10
# /home/piai/anaconda3/lib/python3.10/site-packages/keras/src/layers/layer.py:372: UserWarning: `build()` was called on layer 'cnn_7', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 35s 87ms/step - accuracy: 0.6704 - loss: 0.9886 - val_accuracy: 0.9739 - val_loss: 0.0921
# Epoch 2/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 34s 86ms/step - accuracy: 0.9769 - loss: 0.0723 - val_accuracy: 0.9842 - val_loss: 0.0540
# Epoch 3/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 34s 86ms/step - accuracy: 0.9857 - loss: 0.0454 - val_accuracy: 0.9853 - val_loss: 0.0479
# Epoch 4/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 34s 86ms/step - accuracy: 0.9904 - loss: 0.0313 - val_accuracy: 0.9827 - val_loss: 0.0547
# Epoch 5/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 34s 86ms/step - accuracy: 0.9918 - loss: 0.0252 - val_accuracy: 0.9854 - val_loss: 0.0459
# Epoch 6/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 34s 86ms/step - accuracy: 0.9934 - loss: 0.0205 - val_accuracy: 0.9866 - val_loss: 0.0424
# Epoch 7/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9947 - loss: 0.0169 - val_accuracy: 0.9895 - val_loss: 0.0346
# Epoch 8/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 34s 86ms/step - accuracy: 0.9960 - loss: 0.0138 - val_accuracy: 0.9899 - val_loss: 0.0350
# Epoch 9/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.9968 - loss: 0.0107 - val_accuracy: 0.9906 - val_loss: 0.0333
# Epoch 10/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 34s 86ms/step - accuracy: 0.9972 - loss: 0.0094 - val_accuracy: 0.9908 - val_loss: 0.0351
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9884 - loss: 0.0368
